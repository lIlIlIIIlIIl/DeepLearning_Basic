# %% [markdown]
# <a href="https://colab.research.google.com/github/lIlIlIIIlIIl/DeepLearning_Basic/blob/main/Assignment_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir results

# %%
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import argparse
import numpy as np
import time
from copy import deepcopy # Add Deepcopy for args
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data

# %%
transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainset, valset = torch.utils.data.random_split(trainset, [40000, 10000])
testset = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
partition = {'train': trainset, 'val':valset, 'test':testset}
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:20<00:00, 8491535.29it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %% [markdown]
# # Model Code

# %%
cfg = {
    'VGG11': [64, 'M', 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG13': [64, 64, 'M', 128, 128, 'M', 256, 256, 'M', 512, 512, 'M', 512, 512, 'M'],
    'VGG16': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 'M', 512, 512, 512, 'M', 512, 512, 512, 'M'],
    'VGG19': [64, 64, 'M', 128, 128, 'M', 256, 256, 256, 256, 'M', 512, 512, 512, 512, 'M', 512, 512, 512, 512, 'M'],
}

# %% [markdown]
# # Model

# %%
class CNN(nn.Module):
    def __init__(self, model_code, in_channels, kernel_size, stride, out_dim, hid_dim, act_func, use_bn, dropout):
        super(CNN, self).__init__()
        self.model_code = model_code
        self.in_channels = in_channels
        self.kernel_size = kernel_size
        self.stride = stride
        self.out_dim = out_dim
        self.hid_dim = hid_dim
        self.act_func = act_func
        self.use_bn = use_bn
        self.Dropout = nn.Dropout(dropout)
        self.padding = self.kernel_size // 2


        if (32 - self.kernel_size + 2*self.padding)/self.stride + 1 != 32:
            raise ValueError('filter is not valid')


        if self.act_func == 'relu':
            self.act_func = nn.ReLU()
        elif self.acact_funct == 'tanh':
            self.act_func == nn.Tanh()
        elif self.act_func == 'sigmoid':
            self.act_func = nn.Sigmoid()
        else:
            raise ValueError('no valid activation function selected!')

        self.layers = self._make_layers()
        self.classifier = nn.Sequential(nn.Linear(512, self.hid_dim),
                                        self.act_func,
                                        nn.Linear(self.hid_dim, self.out_dim),
                                        self.Dropout)

    def _make_layers(self):
        layers = [] # Sequential을 사용하기 위해 ModuleList가 아닌 그냥 List 사용
        for x in cfg[self.model_code]:
            if x == 'M':
                layers += [nn.MaxPool2d(2, 2)]

            else:
                layers += [nn.Conv2d(self.in_channels, x, self.kernel_size, self.stride, self.padding)]
                if self.use_bn:
                    layers += [nn.BatchNorm2d(x)]
                layers += [self.act_func]
                self.in_channels = x # in_channels 업데이트

        return nn.Sequential(*layers)
        # *layers: layers 리스트의 데이터들을 각각 받아주는 문법(가변 인수 느낌)
        # Sequential은 리스트를 받아서 하나의 서브모델을 만들어주는 문법. CNN모델 내의 layers모델을 서브모델로 만듦

    def forward(self, x):
        x = self.layers(x) # layers가 하나의 서브모델
        x = x.view(x.size(0), -1) # batch size는 그대로 유지하면서 3차원 tensor를 벡터 형태로 펼쳐준다.
        x = self.classifier(x)

        return x

# %% [markdown]
# # Dimenstion Check

# %%
def dimension_check():
    net = CNN('VGG11', 3, 7, 1, 10, 4096, 'relu', True, 0)
    x = torch.randn(2, 3, 32, 32) # 해당 크기를 갖는 임의의 텐서를 생성
    y = net(x)
    print(y.size())

# layer를 쌓을 때마다 dimension이 맞는지 체크해주는 함수

dimension_check()
# Out:
# torch.Size([2, 10])

# %% [markdown]
# # Train

# %%
def train(net, partition, optimizer, criterion, args):
    trainloader = torch.utils.data.DataLoader(partition['train'],
                                              batch_size=args.train_batch_size,
                                              shuffle=True, num_workers=2)
    net.train()

    correct = 0
    total = 0
    train_loss = 0.0
    for i, data in enumerate(trainloader, 0):
        optimizer.zero_grad() # [21.01.05 오류 수정] 매 Epoch 마다 .zero_grad()가 실행되는 것을 매 iteration 마다 실행되도록 수정했습니다.

        # get the inputs
        inputs, labels = data
        # print(inputs.size()) => (batchsize, channel, H, W) = (256, 3, 32, 32). 즉 dataloader가 4차원 텐서 형태로 데이터를 받아놓음; (shape쓰면 안됨)
        inputs = inputs.cuda()
        labels = labels.cuda()
        outputs = net(inputs)

        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()

        train_loss += loss.item()
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    train_loss = train_loss / len(trainloader)
    train_acc = 100 * correct / total
    return net, train_loss, train_acc

# %% [markdown]
# # Validation

# %%
def validate(net, partition, criterion, args):
    valloader = torch.utils.data.DataLoader(partition['val'],
                                            batch_size=args.test_batch_size,
                                            shuffle=False, num_workers=2)
    net.eval()

    correct = 0
    total = 0
    val_loss = 0
    with torch.no_grad():
        for data in valloader:
            images, labels = data
            images = images.cuda()
            labels = labels.cuda()
            outputs = net(images)

            loss = criterion(outputs, labels)

            val_loss += loss.item()
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        val_loss = val_loss / len(valloader)
        val_acc = 100 * correct / total
    return val_loss, val_acc

# %% [markdown]
# # Test

# %%
def test(net, partition, args):
    testloader = torch.utils.data.DataLoader(partition['test'],
                                             batch_size=args.test_batch_size,
                                             shuffle=False, num_workers=2)
    net.eval()

    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images = images.cuda()
            labels = labels.cuda()

            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

        test_acc = 100 * correct / total
    return test_acc

# %% [markdown]
# # Experiment

# %%
def experiment(partition, args):

    net = CNN(args.model_code, args.in_channels, args.kernel_size, args.stride, args.out_dim, args.hid_dim, args.act_func, args.use_bn, args.dropout)
    net.cuda()

    criterion = nn.CrossEntropyLoss()
    if args.optim == 'SGD':
        optimizer = optim.SGD(net.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'RMSprop':
        optimizer = optim.RMSprop(net.parameters(), lr=args.lr, weight_decay=args.l2)
    elif args.optim == 'Adam':
        optimizer = optim.Adam(net.parameters(), lr=args.lr, weight_decay=args.l2)
    else:
        raise ValueError('In-valid optimizer choice')

    train_losses = []
    val_losses = []
    train_accs = []
    val_accs = []

    for epoch in range(args.epoch):  # loop over the dataset multiple times
        ts = time.time()
        net, train_loss, train_acc = train(net, partition, optimizer, criterion, args)
        val_loss, val_acc = validate(net, partition, criterion, args)
        te = time.time()

        train_losses.append(train_loss)
        val_losses.append(val_loss)
        train_accs.append(train_acc)
        val_accs.append(val_acc)

        print('Epoch {}, Acc(train/val): {:2.2f}/{:2.2f}, Loss(train/val) {:2.2f}/{:2.2f}. Took {:2.2f} sec'.format(epoch, train_acc, val_acc, train_loss, val_loss, te-ts))

    test_acc = test(net, partition, args)

    result = {}
    result['train_losses'] = train_losses
    result['val_losses'] = val_losses
    result['train_accs'] = train_accs
    result['val_accs'] = val_accs
    result['train_acc'] = train_acc
    result['val_acc'] = val_acc
    result['test_acc'] = test_acc
    return vars(args), result

# %% [markdown]
# # Load, Save EXP

# %%
import hashlib
import json
from os import listdir
from os.path import isfile, join
import pandas as pd

def save_exp_result(setting, result):
    exp_name = setting['exp_name']
    del setting['epoch']
    del setting['test_batch_size']

    hash_key = hashlib.sha1(str(setting).encode()).hexdigest()[:6]
    filename = './results/{}-{}.json'.format(exp_name, hash_key)
    result.update(setting)
    with open(filename, 'w') as f:
        json.dump(result, f)


def load_exp_result(exp_name):
    dir_path = './results'
    filenames = [f for f in listdir(dir_path) if isfile(join(dir_path, f)) if '.json' in f]
    list_result = []
    for filename in filenames:
        if exp_name in filename:
            with open(join(dir_path, filename), 'r') as infile:
                results = json.load(infile)
                list_result.append(results)
    df = pd.DataFrame(list_result) # .drop(columns=[])
    return df

# %% [markdown]
# # Visualize

# %%
def plot_acc(var1, var2, df):

    fig, ax = plt.subplots(1, 3)
    fig.set_size_inches(15, 6)
    sns.set_style("darkgrid", {"axes.facecolor": ".9"})

    sns.barplot(x=var1, y='train_acc', hue=var2, data=df, ax=ax[0])
    sns.barplot(x=var1, y='val_acc', hue=var2, data=df, ax=ax[1])
    sns.barplot(x=var1, y='test_acc', hue=var2, data=df, ax=ax[2])

    ax[0].set_title('Train Accuracy')
    ax[1].set_title('Validation Accuracy')
    ax[2].set_title('Test Accuracy')


def plot_loss_variation(var1, var2, df, **kwargs):

    list_v1 = df[var1].unique()
    list_v2 = df[var2].unique()
    list_data = []

    for value1 in list_v1:
        for value2 in list_v2:
            row = df.loc[df[var1]==value1]
            row = row.loc[df[var2]==value2]

            train_losses = list(row.train_losses)[0]
            val_losses = list(row.val_losses)[0]

            for epoch, train_loss in enumerate(train_losses):
                list_data.append({'type':'train', 'loss':train_loss, 'epoch':epoch, var1:value1, var2:value2})
            for epoch, val_loss in enumerate(val_losses):
                list_data.append({'type':'val', 'loss':val_loss, 'epoch':epoch, var1:value1, var2:value2})

    df = pd.DataFrame(list_data)
    g = sns.FacetGrid(df, row=var2, col=var1, hue='type', **kwargs)
    g = g.map(plt.plot, 'epoch', 'loss', marker='.')
    g.add_legend()
    g.fig.suptitle('Train loss vs Val loss')
    plt.subplots_adjust(top=0.89) # 만약 Title이 그래프랑 겹친다면 top 값을 조정해주면 됩니다! 함수 인자로 받으면 그래프마다 조절할 수 있겠죠?


def plot_acc_variation(var1, var2, df, **kwargs):
    list_v1 = df[var1].unique()
    list_v2 = df[var2].unique()
    list_data = []

    for value1 in list_v1:
        for value2 in list_v2:
            row = df.loc[df[var1]==value1]
            row = row.loc[df[var2]==value2]

            train_accs = list(row.train_accs)[0]
            val_accs = list(row.val_accs)[0]
            test_acc = list(row.test_acc)[0]

            for epoch, train_acc in enumerate(train_accs):
                list_data.append({'type':'train', 'Acc':train_acc, 'test_acc':test_acc, 'epoch':epoch, var1:value1, var2:value2})
            for epoch, val_acc in enumerate(val_accs):
                list_data.append({'type':'val', 'Acc':val_acc, 'test_acc':test_acc, 'epoch':epoch, var1:value1, var2:value2})

    df = pd.DataFrame(list_data)
    g = sns.FacetGrid(df, row=var2, col=var1, hue='type', **kwargs)
    g = g.map(plt.plot, 'epoch', 'Acc', marker='.')

    def show_acc(x, y, metric, **kwargs):
        plt.scatter(x, y, alpha=0.3, s=1)
        metric = "Test Acc: {:1.3f}".format(list(metric.values)[0])
        plt.text(0.05, 0.95, metric,  horizontalalignment='left', verticalalignment='center', transform=plt.gca().transAxes, bbox=dict(facecolor='yellow', alpha=0.5, boxstyle="round,pad=0.1"))
    g = g.map(show_acc, 'epoch', 'Acc', 'test_acc')

    g.add_legend()
    g.fig.suptitle('Train Accuracy vs Val Accuracy')
    plt.subplots_adjust(top=0.89)

# %% [markdown]
# # Execute

# %%
# ====== Random Seed Initialization ====== #
seed = 123
np.random.seed(seed)
torch.manual_seed(seed)

parser = argparse.ArgumentParser()
args = parser.parse_args("")
args.exp_name = "exp1_n_layer_hid_dim"

# ====== Model Capacity ====== #
args.out_dim = 10
args.hid_dim = 4096
args.act_func = 'relu'
args.model_code = 'VGG13'
args.in_channels = 3
args.kernel_size = 3
args.stride = 1

# ====== Regularization ======= #
args.l2 = 0.00001
args.use_bn = True
args.dropout = 0.1

# ====== Optimizer & Training ====== #
args.optim = 'Adam' #'RMSprop' #SGD, RMSprop, ADAM...
args.lr = 0.0015
args.epoch = 10

args.train_batch_size = 512
args.test_batch_size = 1024

# ====== Experiment Variable ====== #
name_var1 = 'lr'
name_var2 = 'l2'
list_var1 = [0.0001, 0.001, 0.0015, 0.005]
list_var2 = [0.000001, 0.00001,0.0001, 0.001]


for var1 in list_var1:
    for var2 in list_var2:
        setattr(args, name_var1, var1)
        setattr(args, name_var2, var2)
        print(args)

        setting, result = experiment(partition, deepcopy(args))
        save_exp_result(setting, result)
# Out:
# Namespace(exp_name='exp1_n_layer_hid_dim', out_dim=10, hid_dim=4096, act_func='relu', model_code='VGG11', in_channels=3, kernel_size=3, stride=1, l2=1e-05, use_bn=True, dropout=0.1, optim='Adam', lr=0.0015, epoch=10, train_batch_size=512, test_batch_size=1024)
# Epoch 0, Acc(train/val): 15.55/22.58, Loss(train/val) 2.27/1.89. Took 19.27 sec
# Epoch 1, Acc(train/val): 27.37/34.83, Loss(train/val) 1.81/1.66. Took 14.87 sec
# Epoch 2, Acc(train/val): 39.99/38.21, Loss(train/val) 1.57/1.71. Took 15.18 sec
# Epoch 3, Acc(train/val): 49.02/49.25, Loss(train/val) 1.36/1.36. Took 14.31 sec
# Epoch 4, Acc(train/val): 58.06/62.76, Loss(train/val) 1.15/1.03. Took 14.56 sec
# Epoch 5, Acc(train/val): 64.08/67.05, Loss(train/val) 1.00/0.94. Took 14.20 sec
# Epoch 6, Acc(train/val): 69.19/61.58, Loss(train/val) 0.86/1.17. Took 14.55 sec
# Epoch 7, Acc(train/val): 73.64/62.98, Loss(train/val) 0.74/1.21. Took 15.50 sec
# Epoch 8, Acc(train/val): 76.71/66.79, Loss(train/val) 0.67/1.13. Took 15.28 sec
# Epoch 9, Acc(train/val): 79.04/73.12, Loss(train/val) 0.59/0.83. Took 15.11 sec
# Namespace(exp_name='exp1_n_layer_hid_dim', out_dim=10, hid_dim=4096, act_func='relu', model_code='VGG13', in_channels=3, kernel_size=3, stride=1, l2=1e-05, use_bn=True, dropout=0.1, optim='Adam', lr=0.0015, epoch=10, train_batch_size=512, test_batch_size=1024)
# Epoch 0, Acc(train/val): 13.81/10.69, Loss(train/val) 2.41/2.44. Took 17.08 sec
# Epoch 1, Acc(train/val): 22.75/22.76, Loss(train/val) 1.95/1.98. Took 17.43 sec
# Epoch 2, Acc(train/val): 31.50/37.67, Loss(train/val) 1.78/1.62. Took 18.23 sec
# Epoch 3, Acc(train/val): 41.26/46.79, Loss(train/val) 1.56/1.40. Took 17.18 sec
# Epoch 4, Acc(train/val): 51.13/50.82, Loss(train/val) 1.32/1.39. Took 17.00 sec
# Epoch 5, Acc(train/val): 58.44/59.74, Loss(train/val) 1.15/1.11. Took 16.97 sec
# Epoch 6, Acc(train/val): 64.34/63.11, Loss(train/val) 0.99/1.04. Took 17.04 sec
# Epoch 7, Acc(train/val): 69.63/67.65, Loss(train/val) 0.85/0.93. Took 19.01 sec
# Epoch 8, Acc(train/val): 73.89/70.97, Loss(train/val) 0.74/0.88. Took 16.84 sec
# Epoch 9, Acc(train/val): 76.88/73.48, Loss(train/val) 0.66/0.84. Took 17.05 sec
# Namespace(exp_name='exp1_n_layer_hid_dim', out_dim=10, hid_dim=4096, act_func='relu', model_code='VGG16', in_channels=3, kernel_size=3, stride=1, l2=1e-05, use_bn=True, dropout=0.1, optim='Adam', lr=0.0015, epoch=10, train_batch_size=512, test_batch_size=1024)
# Epoch 0, Acc(train/val): 12.28/14.26, Loss(train/val) 2.39/2.22. Took 20.82 sec
# Epoch 1, Acc(train/val): 18.32/22.12, Loss(train/val) 2.05/1.90. Took 19.88 sec
# Epoch 2, Acc(train/val): 24.50/25.84, Loss(train/val) 1.88/1.92. Took 19.63 sec
# Epoch 3, Acc(train/val): 32.09/33.70, Loss(train/val) 1.69/1.72. Took 20.38 sec
# Epoch 4, Acc(train/val): 40.66/44.67, Loss(train/val) 1.53/1.52. Took 20.69 sec
# Epoch 5, Acc(train/val): 49.40/48.78, Loss(train/val) 1.36/1.35. Took 21.19 sec
# Epoch 6, Acc(train/val): 57.65/61.30, Loss(train/val) 1.17/1.09. Took 20.01 sec
# Epoch 7, Acc(train/val): 63.62/62.70, Loss(train/val) 1.02/1.05. Took 19.72 sec
# Epoch 8, Acc(train/val): 67.80/66.95, Loss(train/val) 0.91/0.96. Took 20.63 sec
# Epoch 9, Acc(train/val): 72.03/63.44, Loss(train/val) 0.80/1.19. Took 19.65 sec
# Namespace(exp_name='exp1_n_layer_hid_dim', out_dim=10, hid_dim=4096, act_func='relu', model_code='VGG19', in_channels=3, kernel_size=3, stride=1, l2=1e-05, use_bn=True, dropout=0.1, optim='Adam', lr=0.0015, epoch=10, train_batch_size=512, test_batch_size=1024)
# Epoch 0, Acc(train/val): 11.58/11.67, Loss(train/val) 2.37/2.27. Took 23.02 sec
# Epoch 1, Acc(train/val): 15.93/19.12, Loss(train/val) 2.13/1.93. Took 23.71 sec
# Epoch 2, Acc(train/val): 24.91/20.63, Loss(train/val) 1.87/2.08. Took 23.19 sec
# Epoch 3, Acc(train/val): 31.56/33.99, Loss(train/val) 1.72/1.67. Took 23.21 sec
# Epoch 4, Acc(train/val): 37.58/38.51, Loss(train/val) 1.58/1.59. Took 23.08 sec
# Epoch 5, Acc(train/val): 40.61/38.85, Loss(train/val) 1.50/1.55. Took 23.19 sec
# Epoch 6, Acc(train/val): 45.95/47.44, Loss(train/val) 1.40/1.37. Took 24.39 sec
# Epoch 7, Acc(train/val): 54.75/50.59, Loss(train/val) 1.22/1.47. Took 22.85 sec
# Epoch 8, Acc(train/val): 62.90/60.41, Loss(train/val) 1.03/1.17. Took 23.39 sec
# Epoch 9, Acc(train/val): 67.96/65.65, Loss(train/val) 0.90/1.03. Took 23.31 sec
# Namespace(exp_name='exp1_n_layer_hid_dim', out_dim=10, hid_dim=4096, act_func='relu', model_code='VGG11', in_channels=3, kernel_size=5, stride=1, l2=1e-05, use_bn=True, dropout=0.1, optim='Adam', lr=0.0015, epoch=10, train_batch_size=512, test_batch_size=1024)
# Epoch 0, Acc(train/val): 13.71/15.12, Loss(train/val) 2.38/2.19. Took 35.94 sec
# Epoch 1, Acc(train/val): 18.25/19.84, Loss(train/val) 2.06/1.96. Took 36.05 sec
# Epoch 2, Acc(train/val): 24.10/27.07, Loss(train/val) 1.89/1.83. Took 35.89 sec
# Epoch 3, Acc(train/val): 32.23/34.79, Loss(train/val) 1.73/1.67. Took 36.30 sec
# Epoch 4, Acc(train/val): 40.19/42.16, Loss(train/val) 1.57/1.51. Took 37.18 sec
# Epoch 5, Acc(train/val): 46.82/44.66, Loss(train/val) 1.42/1.49. Took 36.01 sec
# Epoch 6, Acc(train/val): 52.26/51.33, Loss(train/val) 1.28/1.35. Took 36.26 sec
# Epoch 7, Acc(train/val): 59.02/60.65, Loss(train/val) 1.13/1.11. Took 35.86 sec
# Epoch 8, Acc(train/val): 63.91/64.11, Loss(train/val) 1.00/1.04. Took 36.36 sec
# Epoch 9, Acc(train/val): 68.45/61.83, Loss(train/val) 0.89/1.15. Took 36.19 sec
# Namespace(exp_name='exp1_n_layer_hid_dim', out_dim=10, hid_dim=4096, act_func='relu', model_code='VGG13', in_channels=3, kernel_size=5, stride=1, l2=1e-05, use_bn=True, dropout=0.1, optim='Adam', lr=0.0015, epoch=10, train_batch_size=512, test_batch_size=1024)
# Epoch 0, Acc(train/val): 13.39/14.78, Loss(train/val) 2.39/2.24. Took 45.17 sec
# Epoch 1, Acc(train/val): 18.96/13.15, Loss(train/val) 2.07/2.24. Took 45.72 sec
# Epoch 2, Acc(train/val): 23.24/24.35, Loss(train/val) 1.91/1.87. Took 45.60 sec
# Epoch 3, Acc(train/val): 28.94/33.27, Loss(train/val) 1.79/1.73. Took 46.47 sec
# Epoch 4, Acc(train/val): 36.27/38.15, Loss(train/val) 1.64/1.60. Took 45.62 sec
# Epoch 5, Acc(train/val): 43.45/35.74, Loss(train/val) 1.50/1.78. Took 45.65 sec
# Epoch 6, Acc(train/val): 48.47/48.27, Loss(train/val) 1.39/1.45. Took 45.80 sec
# Epoch 7, Acc(train/val): 54.69/55.08, Loss(train/val) 1.24/1.29. Took 45.74 sec
# Epoch 8, Acc(train/val): 60.47/54.89, Loss(train/val) 1.09/1.27. Took 47.34 sec
# Epoch 9, Acc(train/val): 65.31/55.95, Loss(train/val) 0.97/1.35. Took 45.74 sec
# Namespace(exp_name='exp1_n_layer_hid_dim', out_dim=10, hid_dim=4096, act_func='relu', model_code='VGG16', in_channels=3, kernel_size=5, stride=1, l2=1e-05, use_bn=True, dropout=0.1, optim='Adam', lr=0.0015, epoch=10, train_batch_size=512, test_batch_size=1024)
# Epoch 0, Acc(train/val): 13.56/17.25, Loss(train/val) 2.35/2.15. Took 63.11 sec
# Epoch 1, Acc(train/val): 18.70/22.98, Loss(train/val) 2.05/1.91. Took 63.33 sec
# Epoch 2, Acc(train/val): 24.45/28.38, Loss(train/val) 1.89/1.80. Took 64.56 sec
# Epoch 3, Acc(train/val): 29.39/31.06, Loss(train/val) 1.79/1.80. Took 63.26 sec
# Epoch 4, Acc(train/val): 35.58/39.67, Loss(train/val) 1.66/1.58. Took 64.33 sec
# Epoch 5, Acc(train/val): 43.30/36.74, Loss(train/val) 1.51/1.78. Took 63.42 sec
# Epoch 6, Acc(train/val): 50.83/48.45, Loss(train/val) 1.34/1.48. Took 63.48 sec
# Epoch 7, Acc(train/val): 56.45/52.81, Loss(train/val) 1.19/1.35. Took 63.47 sec
# Epoch 8, Acc(train/val): 60.72/60.18, Loss(train/val) 1.08/1.17. Took 63.48 sec
# Epoch 9, Acc(train/val): 63.28/54.44, Loss(train/val) 1.02/1.43. Took 63.42 sec
# Namespace(exp_name='exp1_n_layer_hid_dim', out_dim=10, hid_dim=4096, act_func='relu', model_code='VGG19', in_channels=3, kernel_size=5, stride=1, l2=1e-05, use_bn=True, dropout=0.1, optim='Adam', lr=0.0015, epoch=10, train_batch_size=512, test_batch_size=1024)
# Epoch 0, Acc(train/val): 10.22/11.27, Loss(train/val) 2.41/2.30. Took 80.23 sec
# Epoch 1, Acc(train/val): 11.55/12.32, Loss(train/val) 2.28/2.27. Took 80.07 sec
# Epoch 2, Acc(train/val): 14.31/9.75, Loss(train/val) 2.21/2.37. Took 81.45 sec
# Epoch 3, Acc(train/val): 18.12/19.06, Loss(train/val) 2.10/2.05. Took 80.89 sec
# Epoch 4, Acc(train/val): 22.78/26.97, Loss(train/val) 1.92/1.83. Took 81.24 sec
# Epoch 5, Acc(train/val): 27.42/33.08, Loss(train/val) 1.83/1.72. Took 81.05 sec
# Epoch 6, Acc(train/val): 35.50/30.47, Loss(train/val) 1.70/1.82. Took 80.90 sec
# Epoch 7, Acc(train/val): 38.76/33.78, Loss(train/val) 1.60/1.76. Took 81.65 sec
# Epoch 8, Acc(train/val): 44.51/42.76, Loss(train/val) 1.46/1.47. Took 81.56 sec
# Epoch 9, Acc(train/val): 47.76/46.56, Loss(train/val) 1.34/1.45. Took 81.17 sec
# Namespace(exp_name='exp1_n_layer_hid_dim', out_dim=10, hid_dim=4096, act_func='relu', model_code='VGG11', in_channels=3, kernel_size=7, stride=1, l2=1e-05, use_bn=True, dropout=0.1, optim='Adam', lr=0.0015, epoch=10, train_batch_size=512, test_batch_size=1024)
# Epoch 0, Acc(train/val): 11.38/12.19, Loss(train/val) 2.44/2.29. Took 52.61 sec
# Epoch 1, Acc(train/val): 13.43/15.20, Loss(train/val) 2.26/2.20. Took 52.66 sec
# Epoch 2, Acc(train/val): 18.54/16.19, Loss(train/val) 2.06/2.05. Took 53.03 sec
# Epoch 3, Acc(train/val): 23.21/27.31, Loss(train/val) 1.93/1.82. Took 53.67 sec
# Epoch 4, Acc(train/val): 30.12/32.69, Loss(train/val) 1.79/1.72. Took 53.29 sec
# Epoch 5, Acc(train/val): 37.20/39.93, Loss(train/val) 1.62/1.54. Took 53.29 sec
# Epoch 6, Acc(train/val): 43.35/44.78, Loss(train/val) 1.49/1.49. Took 53.25 sec
# Epoch 7, Acc(train/val): 48.37/43.15, Loss(train/val) 1.38/1.52. Took 53.27 sec
# Epoch 8, Acc(train/val): 53.40/54.92, Loss(train/val) 1.26/1.21. Took 54.20 sec
# Epoch 9, Acc(train/val): 58.66/63.01, Loss(train/val) 1.14/1.03. Took 53.29 sec
# Namespace(exp_name='exp1_n_layer_hid_dim', out_dim=10, hid_dim=4096, act_func='relu', model_code='VGG13', in_channels=3, kernel_size=7, stride=1, l2=1e-05, use_bn=True, dropout=0.1, optim='Adam', lr=0.0015, epoch=10, train_batch_size=512, test_batch_size=1024)
# Epoch 0, Acc(train/val): 12.86/14.59, Loss(train/val) 2.40/2.24. Took 69.10 sec
# Epoch 1, Acc(train/val): 15.77/15.68, Loss(train/val) 2.17/2.11. Took 69.18 sec
# Epoch 2, Acc(train/val): 19.64/23.25, Loss(train/val) 2.02/1.94. Took 69.69 sec
# Epoch 3, Acc(train/val): 23.88/25.60, Loss(train/val) 1.92/1.85. Took 69.74 sec
# Epoch 4, Acc(train/val): 28.49/32.00, Loss(train/val) 1.83/1.75. Took 69.60 sec
# Epoch 5, Acc(train/val): 33.65/31.02, Loss(train/val) 1.72/1.84. Took 69.72 sec
# Epoch 6, Acc(train/val): 36.92/38.13, Loss(train/val) 1.65/1.66. Took 69.75 sec
# Epoch 7, Acc(train/val): 41.14/45.26, Loss(train/val) 1.55/1.49. Took 69.58 sec
# Epoch 8, Acc(train/val): 46.16/42.54, Loss(train/val) 1.43/1.54. Took 69.76 sec
# Epoch 9, Acc(train/val): 51.12/52.33, Loss(train/val) 1.32/1.30. Took 70.01 sec
# Namespace(exp_name='exp1_n_layer_hid_dim', out_dim=10, hid_dim=4096, act_func='relu', model_code='VGG16', in_channels=3, kernel_size=7, stride=1, l2=1e-05, use_bn=True, dropout=0.1, optim='Adam', lr=0.0015, epoch=10, train_batch_size=512, test_batch_size=1024)
# Epoch 0, Acc(train/val): 12.55/13.95, Loss(train/val) 2.42/2.23. Took 95.60 sec
# Epoch 1, Acc(train/val): 14.28/9.61, Loss(train/val) 2.23/2.36. Took 95.74 sec
# Epoch 2, Acc(train/val): 16.73/11.93, Loss(train/val) 2.14/2.30. Took 96.37 sec
# Epoch 3, Acc(train/val): 20.05/18.94, Loss(train/val) 2.02/2.05. Took 96.83 sec
# Epoch 4, Acc(train/val): 24.11/27.70, Loss(train/val) 1.91/1.87. Took 97.39 sec
# Epoch 5, Acc(train/val): 27.89/32.06, Loss(train/val) 1.84/1.75. Took 96.91 sec
# Epoch 6, Acc(train/val): 32.12/28.14, Loss(train/val) 1.75/1.85. Took 96.84 sec
# Epoch 7, Acc(train/val): 34.99/36.85, Loss(train/val) 1.68/1.66. Took 97.08 sec
# Epoch 8, Acc(train/val): 39.28/35.87, Loss(train/val) 1.60/1.94. Took 97.16 sec
# Epoch 9, Acc(train/val): 43.33/37.37, Loss(train/val) 1.51/1.87. Took 97.11 sec
# Namespace(exp_name='exp1_n_layer_hid_dim', out_dim=10, hid_dim=4096, act_func='relu', model_code='VGG19', in_channels=3, kernel_size=7, stride=1, l2=1e-05, use_bn=True, dropout=0.1, optim='Adam', lr=0.0015, epoch=10, train_batch_size=512, test_batch_size=1024)
# Epoch 0, Acc(train/val): 12.04/12.72, Loss(train/val) 2.40/2.26. Took 122.65 sec
# Epoch 1, Acc(train/val): 12.98/9.57, Loss(train/val) 2.25/2.32. Took 122.31 sec
# Epoch 2, Acc(train/val): 15.44/17.65, Loss(train/val) 2.18/2.10. Took 123.00 sec
# Epoch 3, Acc(train/val): 17.79/15.47, Loss(train/val) 2.11/2.16. Took 123.77 sec
# Epoch 4, Acc(train/val): 21.73/21.21, Loss(train/val) 1.96/1.94. Took 124.06 sec
# Epoch 5, Acc(train/val): 25.18/26.44, Loss(train/val) 1.89/1.86. Took 124.21 sec
# Epoch 6, Acc(train/val): 27.76/28.59, Loss(train/val) 1.84/1.83. Took 124.11 sec
# Epoch 7, Acc(train/val): 32.12/34.08, Loss(train/val) 1.75/1.67. Took 124.59 sec
# Epoch 8, Acc(train/val): 35.63/35.36, Loss(train/val) 1.68/1.67. Took 124.33 sec
# Epoch 9, Acc(train/val): 39.56/40.32, Loss(train/val) 1.60/1.58. Took 124.53 sec

# %% [markdown]
# # Plot

# %%
var1 = 'kernel_size'
var2 = 'model_code'
df = load_exp_result('exp1')

plot_acc(var1, var2, df)
plot_loss_variation(var1, var2, df, sharey=False) #sharey를 True로 하면 모둔 subplot의 y축의 스케일이 같아집니다.
plot_acc_variation(var1, var2, df, margin_titles=True, sharey=True) #margin_titles를 True로 하면 그래프의 가장자리에 var1과 var2 값이 표시되고 False로 하면 각 subplot 위에 표시됩니다.
